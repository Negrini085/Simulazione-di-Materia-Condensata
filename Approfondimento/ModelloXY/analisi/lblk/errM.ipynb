# %% [markdown]
# <center>
#
# # <span style="color:red"> Studio dimensione blocchi </span>
#
# </center>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

from scipy.optimize import curve_fit

# %% [markdown]
# ## Esempio di determinazione dimensione blocco

# %%
obs = np.loadtxt("sim/lblk_t1.0_size100_seed1.out")
magn = obs[:, 1]


err = np.zeros(200)

#Ciclo per le varie lunghezze dei blocchi
for i in range(5, 1001, 5):
    m = 0
    m2 = 0
    
    # Ciclo per l'errore a lunghezza del blocco fissata
    for j in range(0, math.floor(len(magn)/i)):
        mblk = 0
        m2blk = 0

        # Stima nel singolo blocco
        for k in range(0, i):
            mblk += magn[i * j + k]/i

        m = m * j/(j+1)+  mblk/(j+1)
        m2 = m2 * j/(j+1)+  mblk*mblk/(j+1)
    
    err[math.floor(i/5)-1] = math.sqrt((m2 - m**2)/(math.floor(len(magn)/i)-1))

# %%
fig = plt.figure(figsize=(15, 6))

plt.plot(np.linspace(5, 1001, 200), err)
plt.title("Stima lunghezza blocco")
plt.ylabel('Errore')
plt.xlabel('Lunghezza blocco')
plt.grid()

plt.show()

# %% [markdown]
# ## Studio sistematico spazio dei parametri

# %%
def err_lblk(x, lmax, sp_camp, num):
    err = np.zeros(num)

    #Ciclo per le varie lunghezze dei blocchi
    for i in range(5, lmax, sp_camp):
        m = 0
        m2 = 0

        # Ciclo per l'errore a lunghezza del blocco fissata
        for j in range(0, math.floor(len(x)/i)):
            mblk = 0
            m2blk = 0

            # Stima nel singolo blocco
            for k in range(0, i):
                mblk += x[i * j + k]/i

            m = m * j/(j+1)+  mblk/(j+1)
            m2 = m2 * j/(j+1)+  mblk*mblk/(j+1)

        err[math.floor(i/sp_camp)-1] = math.sqrt((m2 - m**2)/(math.floor(len(x)/i)-1))

    return err

# %%
temp_t = np.array(['0.5', '1.0'])
size_t = np.array(['50','100', '200'])
seed_t = np.array(['1', '2', '3', '4'])

lmax = 10001
sp_camp = 10

err = np.zeros(shape = (4, 1000))

for size in size_t:
    for i in range(0, len(temp_t)):
        for j in range(0, len(seed_t)):
        
            # Leggo il file
            fname = 'sim/lblk_t' + temp_t[i] + '_size' + size + '_seed'+ seed_t[j] +'.out'
            obs = np.loadtxt(fname)
            magn = np.sqrt(obs[:, 2]**2 + obs[:, 3]**2)

            # Calcolo dell'errore e memorizzazione
            err[j, :] = err_lblk(magn, lmax, sp_camp, 1000)
        print("Calcolato errore: N = " + size + ", T = " + temp_t[i])

        fout = 'err/errM_size' + size + '_t' + temp_t[i] + '.dat'
        np.savetxt(fout, err.T, delimiter=' ', fmt='%.8f')
# Out:
# Calcolato errore: N = 50, T = 0.5
# Calcolato errore: N = 50, T = 1.0
# Calcolato errore: N = 100, T = 0.5
# Calcolato errore: N = 100, T = 1.0
# Calcolato errore: N = 200, T = 0.5
# Calcolato errore: N = 200, T = 1.0

# %%
temp_t = np.array(['1.5', '2.0', '2.5', '3.0'])
size_t = np.array(['50','100', '200'])
seed_t = np.array(['1', '2', '3', '4'])

lmax = 2001
sp_camp = 10

err = np.zeros(shape = (4, 200))

for size in size_t:
    for i in range(0, len(temp_t)):
        for j in range(0, len(seed_t)):
        
            # Leggo il file
            fname = 'sim/lblk_t' + temp_t[i] + '_size' + size + '_seed'+ seed_t[j] +'.out'
            obs = np.loadtxt(fname)
            magn = np.sqrt(obs[:, 2]**2 + obs[:, 2]**2)

            # Calcolo dell'errore e memorizzazione
            err[j, :] = err_lblk(magn, lmax, sp_camp, 200)
        print("Calcolato errore: N = " + size + ", T = " + temp_t[i])

        fout = 'err/errM_size' + size + '_t' + temp_t[i] + '.dat'
        np.savetxt(fout, err.T, delimiter=' ', fmt='%.8f')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 20
#      17     magn = obs[:, 2]
#      19     # Calcolo dell'errore e memorizzazione
# ---> 20     err[j, :] = err_lblk(magn, lmax, sp_camp, 200)
#      21 print("Calcolato errore: N = " + size + ", T = " + temp_t[i])
#      23 fout = 'err/errM_size' + size + '_t' + temp_t[i] + '.dat'
#
# ValueError: could not broadcast input array from shape (200,) into shape (1000,)
